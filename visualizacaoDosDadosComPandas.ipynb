# %%
import pandas as pd

dataset = pd.read_csv('kc_house_data.csv', sep = ',')

# %%
##plot de gráfico apenas com a coluna preço no eixo x e a quantidade delas no eixo y
# %matplotlib notebook
dataset['price'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##plot de gráfico no eixo x o numero de quartos e no eixo y o preços dos imóveis, kind informo que o gráfico
##é do tipo scatter
dataset.plot(x='bedrooms', y='price', kind='scatter', title='Bedrooms x Price', color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##plot de gráfico no eixo x o numero de banheiros e no eixo y o preços dos imóveis, kind informo que o gráfico
##é do tipo scatter
dataset.plot(x='bathrooms', y='price', kind='scatter', title='Bathrooms x Price', color='y')
# Out:
# <img src="data:image/png;base64,..." width="640">
